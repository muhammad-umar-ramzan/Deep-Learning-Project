# %%
import warnings
warnings.filterwarnings('ignore') 
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
new_model=keras.models.load_model("Skin_Cancer_Detector.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
image=input("Enter the path of Image:")
import cv2
test_image=cv2.imread(image)
plt.imshow(test_image)
test_image=cv2.resize(test_image,(256,256))
test_input=test_image.reshape((1,256,256,3))
arr=new_model.predict(test_input)
if (round(arr[0][0],0)==0):
    print("Benign")
elif(round(arr[0][0],0)==1):
    print("malignant")
# Out:
# Enter the path of Image: WhatsApp Image 2024-10-25 at 11.30.33_e1584e36.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# malignant
